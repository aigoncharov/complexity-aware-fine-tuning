# %%
import pandas as pd

df = pd.read_csv(
    "../../data/out/masj/mmlu_masj_education_levels.tsv",
    sep="\t",
    header=0,
)

# %%
df
# Out:
#                                        src answer  \
# 0                   ori_mmlu-jurisprudence      C
# 1               ori_mmlu-international_law      E
# 2                      ori_mmlu-management      D
# 3                          stemez-Business      J
# 4                          stemez-Business      I
# ...                                    ...    ...
# 12027  ori_mmlu-high_school_macroeconomics      F
# 12028  ori_mmlu-high_school_macroeconomics      A
# 12029  ori_mmlu-high_school_macroeconomics      I
# 12030  ori_mmlu-high_school_macroeconomics      B
# 12031  ori_mmlu-high_school_macroeconomics      J
#
#                                                  options   category  \
# 0      ['There is no distinction between the two form...        law
# 1      ['Article 19', 'Article 11', 'Article 12', 'Ar...        law
# 2      ['Work delegation', 'Workload balancing', 'Wor...   business
# 3      ['$308.25', '$142.75', '$199.99', '$225.85', '...   business
# ...

# %%
len(df)
# Out:
# 12032

# %%
df.columns
# Out:
# Index(['src', 'answer', 'options', 'category', 'question', 'cot_content',
#        'question_id', 'answer_index', 'total_tokens', 'meta_cluster',
#        'base_cluster', 'masj_complexity', 'masj_rating'],
#       dtype='object')

# %%
df = df[df["masj_rating"] >= 9]

# %%
df
# Out:
#                                        src answer  \
# 0                   ori_mmlu-jurisprudence      C
# 1               ori_mmlu-international_law      E
# 2                      ori_mmlu-management      D
# 3                          stemez-Business      J
# 4                          stemez-Business      I
# ...                                    ...    ...
# 12027  ori_mmlu-high_school_macroeconomics      F
# 12028  ori_mmlu-high_school_macroeconomics      A
# 12029  ori_mmlu-high_school_macroeconomics      I
# 12030  ori_mmlu-high_school_macroeconomics      B
# 12031  ori_mmlu-high_school_macroeconomics      J
#
#                                                  options   category  \
# 0      ['There is no distinction between the two form...        law
# 1      ['Article 19', 'Article 11', 'Article 12', 'Ar...        law
# 2      ['Work delegation', 'Workload balancing', 'Wor...   business
# 3      ['$308.25', '$142.75', '$199.99', '$225.85', '...   business
# ...

# %%
df.rename(columns={"masj_complexity": "masj_education_level"}, inplace=True)
# Out:
# /var/folders/62/r46p4vgs7m5bbync7hl0ykjc0000gp/T/ipykernel_11907/2377708883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"masj_complexity": "masj_education_level"}, inplace=True)

# %%
df.drop(columns=["masj_rating"], inplace=True)
# Out:
# /var/folders/62/r46p4vgs7m5bbync7hl0ykjc0000gp/T/ipykernel_11907/3479127213.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["masj_rating"], inplace=True)

# %%
df.value_counts("masj_education_level")
# Out:
# masj_education_level
# undergraduate             6736
# high_school_and_easier    2378
# graduate                  2347
# postgraduate               106
# Name: count, dtype: int64

# %%
df.to_csv("../../data/out/masj/mmlu_masj_education_level_filtered.tsv", sep="\t", index=False)
